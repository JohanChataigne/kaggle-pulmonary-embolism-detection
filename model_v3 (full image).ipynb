# %% [markdown]
# # Third model
#
# This model will try to predict wether pe is present or not on a full image (RGB level)

# %% [markdown]
# ## Imports

# %%
import numpy as np
from balance import *
from model import *
from torchsummary import summary

# %%
import torch
torch.cuda.empty_cache()

print(f'PyTorch version: {torch.__version__}')
print("GPU found :)" if torch.cuda.is_available() else "No GPU :(")

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
# Out:
# PyTorch version: 1.7.1
# GPU found :)

# %% [markdown]
# # Load datasets

# %%
full_image_dataset = torch.load('datasets/full_image_dataset.pt')

# %% [markdown]
# ## CNN

# %%
class ModelV3(nn.Module):
    
    def __init__(self, input_channels):
        """Convnet with 4 convolution layer + pooling + BN, with 3 fully connected at the end"""
        super().__init__()
        
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 64, 3)
        self.bn4 = nn.BatchNorm2d(64)
        
        self.pool = nn.MaxPool2d(kernel_size=2)
        
        self.fc1 = nn.Linear(64*14*14 , 512)
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 1)
        
        self.dropout = nn.Dropout(0.5)
        
        self.sigmoid = nn.Sigmoid()
        
        
    def forward(self, x):
        
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.pool(F.relu(self.bn3(self.conv3(x))))
        x = self.pool(F.relu(self.bn4(self.conv4(x))))
        x = x.view(-1, 64*14*14) # Flatten
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        
        # Binary classification
        out = self.sigmoid(self.fc3(x))
        
        return out

# %%
model = ModelV3(3).to(device)
summary(model, (3, 256, 256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 252, 252]           2,432
#        BatchNorm2d-2         [-1, 32, 252, 252]              64
#          MaxPool2d-3         [-1, 32, 126, 126]               0
#             Conv2d-4         [-1, 64, 124, 124]          18,496
#        BatchNorm2d-5         [-1, 64, 124, 124]             128
#          MaxPool2d-6           [-1, 64, 62, 62]               0
#             Conv2d-7           [-1, 64, 60, 60]          36,928
#        BatchNorm2d-8           [-1, 64, 60, 60]             128
#          MaxPool2d-9           [-1, 64, 30, 30]               0
#            Conv2d-10           [-1, 64, 28, 28]          36,928
#       BatchNorm2d-11           [-1, 64, 28, 28]             128
#         MaxPool2d-12           [-1, 64, 14, 14]               0
#           Dropout-13                [-1, 12544]               0
#            Linear-14                  [-1, 512]       6,423,040
#           Dropout-15                  [-1, 512]               0
#            Linear-16                  [-1, 128]          65,664
#            Linear-17                    [-1, 1]             129
#           Sigmoid-18                    [-1, 1]               0
# ================================================================
# Total params: 6,584,065
# Trainable params: 6,584,065
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 56.70
# Params size (MB): 25.12
# Estimated Total Size (MB): 82.56
# ----------------------------------------------------------------

# %% [markdown]
# ## Split data into train and test

# %%
batch_size = 8
ratio=0.2

train_loader, test_loader = train_test_split(full_image_dataset, ratio, batch_size)

# %% [markdown]
# ## Model Training

# %%
num_epoch = 30
criterion = nn.BCELoss()
optimizer=optim.Adam(model.parameters(), lr=0.001)
save_filename = './models/model_v3.h5'

model, losses = train(model, num_epoch, criterion, train_loader, optimizer, device, save_filename)
# Out:
# Epoch [1/20], step [10/157], loss: 0.8548
# Epoch [1/20], step [20/157], loss: 0.4556
# Epoch [1/20], step [30/157], loss: 0.9078
# Epoch [1/20], step [40/157], loss: 1.0192
# Epoch [1/20], step [50/157], loss: 0.2572
# Epoch [1/20], step [60/157], loss: 0.4021
# Epoch [1/20], step [70/157], loss: 0.9743
# Epoch [1/20], step [80/157], loss: 0.4781
# Epoch [1/20], step [90/157], loss: 0.3997
# Epoch [1/20], step [100/157], loss: 0.5169
# Epoch [1/20], step [110/157], loss: 0.4380
# Epoch [1/20], step [120/157], loss: 0.3004
# Epoch [1/20], step [130/157], loss: 0.5137
# Epoch [1/20], step [140/157], loss: 0.7301
# Epoch [1/20], step [150/157], loss: 0.6277
# Epoch [2/20], step [10/157], loss: 0.7538
# Epoch [2/20], step [20/157], loss: 0.6407
# Epoch [2/20], step [30/157], loss: 0.4411
# Epoch [2/20], step [40/157], loss: 0.3688
# Epoch [2/20], step [50/157], loss: 0.4121
# Epoch [2/20], step [60/157], loss: 0.3587
# Epoch [2/20], step [70/157], loss: 0.5705
# Epoch [2/20], step [80/157], loss: 0.3666
# Epoch [2/20], step [90/157], loss: 0.4937
# Epoch [2/20], step [100/157], loss: 0.5493
# Epoch [2/20], step [110/157], loss: 1.1835
# Epoch [2/20], step [120/157], loss: 0.5313
# Epoch [2/20], step [130/157], loss: 0.3935
# Epoch [2/20], step [140/157], loss: 0.6184
# Epoch [2/20], step [150/157], loss: 0.1800
# Epoch [3/20], step [10/157], loss: 0.2679
# Epoch [3/20], step [20/157], loss: 0.5747
# Epoch [3/20], step [30/157], loss: 0.6652
# Epoch [3/20], step [40/157], loss: 0.1750
# Epoch [3/20], step [50/157], loss: 0.5764
# Epoch [3/20], step [60/157], loss: 0.6152
# Epoch [3/20], step [70/157], loss: 0.4498
# Epoch [3/20], step [80/157], loss: 0.1812
# Epoch [3/20], step [90/157], loss: 0.3535
# Epoch [3/20], step [100/157], loss: 0.3947
# Epoch [3/20], step [110/157], loss: 0.3692
# Epoch [3/20], step [120/157], loss: 0.4875
# Epoch [3/20], step [130/157], loss: 0.5571
# Epoch [3/20], step [140/157], loss: 0.2436
# Epoch [3/20], step [150/157], loss: 0.4433
# Epoch [4/20], step [10/157], loss: 0.4746
# Epoch [4/20], step [20/157], loss: 0.1695
# Epoch [4/20], step [30/157], loss: 0.2095
# Epoch [4/20], step [40/157], loss: 0.5831
# Epoch [4/20], step [50/157], loss: 0.3288
# Epoch [4/20], step [60/157], loss: 0.3649
# Epoch [4/20], step [70/157], loss: 0.5512
# Epoch [4/20], step [80/157], loss: 0.4595
# Epoch [4/20], step [90/157], loss: 0.1913
# Epoch [4/20], step [100/157], loss: 0.8004
# Epoch [4/20], step [110/157], loss: 0.5454
# Epoch [4/20], step [120/157], loss: 0.3983
# Epoch [4/20], step [130/157], loss: 0.5393
# Epoch [4/20], step [140/157], loss: 0.4240
# Epoch [4/20], step [150/157], loss: 0.2634
# Epoch [5/20], step [10/157], loss: 0.3995
# Epoch [5/20], step [20/157], loss: 0.2829
# Epoch [5/20], step [30/157], loss: 0.3238
# Epoch [5/20], step [40/157], loss: 0.2349
# Epoch [5/20], step [50/157], loss: 0.3885
# Epoch [5/20], step [60/157], loss: 0.4359
# Epoch [5/20], step [70/157], loss: 0.2135
# Epoch [5/20], step [80/157], loss: 0.5987
# Epoch [5/20], step [90/157], loss: 0.3309
# Epoch [5/20], step [100/157], loss: 0.2173
# Epoch [5/20], step [110/157], loss: 0.6390
# Epoch [5/20], step [120/157], loss: 0.2219
# Epoch [5/20], step [130/157], loss: 0.7168
# Epoch [5/20], step [140/157], loss: 0.5776
# Epoch [5/20], step [150/157], loss: 0.4387
# Epoch [6/20], step [10/157], loss: 0.2055
# Epoch [6/20], step [20/157], loss: 0.4672
# Epoch [6/20], step [30/157], loss: 0.5377
# Epoch [6/20], step [40/157], loss: 0.5444
# Epoch [6/20], step [50/157], loss: 0.4853
# Epoch [6/20], step [60/157], loss: 0.3373
# Epoch [6/20], step [70/157], loss: 0.3445
# Epoch [6/20], step [80/157], loss: 0.5670
# Epoch [6/20], step [90/157], loss: 0.6286
# Epoch [6/20], step [100/157], loss: 0.3030
# Epoch [6/20], step [110/157], loss: 0.4338
# Epoch [6/20], step [120/157], loss: 0.3831
# Epoch [6/20], step [130/157], loss: 0.4861
# Epoch [6/20], step [140/157], loss: 0.3284
# Epoch [6/20], step [150/157], loss: 0.2778
# Epoch [7/20], step [10/157], loss: 0.7319
# Epoch [7/20], step [20/157], loss: 0.4849
# Epoch [7/20], step [30/157], loss: 0.7599
# Epoch [7/20], step [40/157], loss: 0.2058
# Epoch [7/20], step [50/157], loss: 0.4129
# Epoch [7/20], step [60/157], loss: 0.8925
# Epoch [7/20], step [70/157], loss: 0.2122
# Epoch [7/20], step [80/157], loss: 0.3396
# Epoch [7/20], step [90/157], loss: 0.5086
# Epoch [7/20], step [100/157], loss: 0.2887
# Epoch [7/20], step [110/157], loss: 0.4233
# Epoch [7/20], step [120/157], loss: 0.5024
# Epoch [7/20], step [130/157], loss: 0.1321
# Epoch [7/20], step [140/157], loss: 0.3795
# Epoch [7/20], step [150/157], loss: 0.4076
# Epoch [8/20], step [10/157], loss: 0.1770
# Epoch [8/20], step [20/157], loss: 0.1891
# Epoch [8/20], step [30/157], loss: 0.2562
# Epoch [8/20], step [40/157], loss: 0.8540
# Epoch [8/20], step [50/157], loss: 0.4628
# Epoch [8/20], step [60/157], loss: 0.4690
# Epoch [8/20], step [70/157], loss: 0.2105
# Epoch [8/20], step [80/157], loss: 0.4969
# Epoch [8/20], step [90/157], loss: 0.2561
# Epoch [8/20], step [100/157], loss: 0.3653
# Epoch [8/20], step [110/157], loss: 0.3514
# Epoch [8/20], step [120/157], loss: 0.8651
# Epoch [8/20], step [130/157], loss: 0.2741
# Epoch [8/20], step [140/157], loss: 0.4981
# Epoch [8/20], step [150/157], loss: 0.4002
# Epoch [9/20], step [10/157], loss: 0.5620
# Epoch [9/20], step [20/157], loss: 0.2805
# Epoch [9/20], step [30/157], loss: 0.1736
# Epoch [9/20], step [40/157], loss: 0.3996
# Epoch [9/20], step [50/157], loss: 0.2495
# Epoch [9/20], step [60/157], loss: 0.3791
# Epoch [9/20], step [70/157], loss: 0.0373
# Epoch [9/20], step [80/157], loss: 1.3383
# Epoch [9/20], step [90/157], loss: 0.4949
# Epoch [9/20], step [100/157], loss: 0.1917
# Epoch [9/20], step [110/157], loss: 0.4462
# Epoch [9/20], step [120/157], loss: 0.3390
# Epoch [9/20], step [130/157], loss: 0.1866
# Epoch [9/20], step [140/157], loss: 0.0687
# Epoch [9/20], step [150/157], loss: 0.3250
# Epoch [10/20], step [10/157], loss: 0.4411
# Epoch [10/20], step [20/157], loss: 0.2781
# Epoch [10/20], step [30/157], loss: 0.6207
# Epoch [10/20], step [40/157], loss: 0.1734
# Epoch [10/20], step [50/157], loss: 0.4580
# Epoch [10/20], step [60/157], loss: 0.1310
# Epoch [10/20], step [70/157], loss: 0.1007
# Epoch [10/20], step [80/157], loss: 0.2498
# Epoch [10/20], step [90/157], loss: 0.2239
# Epoch [10/20], step [100/157], loss: 0.6222
# Epoch [10/20], step [110/157], loss: 0.2089
# Epoch [10/20], step [120/157], loss: 0.4201
# Epoch [10/20], step [130/157], loss: 0.5494
# Epoch [10/20], step [140/157], loss: 0.3592
# Epoch [10/20], step [150/157], loss: 0.5492
# Epoch [11/20], step [10/157], loss: 0.2355
# Epoch [11/20], step [20/157], loss: 0.2850
# Epoch [11/20], step [30/157], loss: 0.0570
# Epoch [11/20], step [40/157], loss: 0.1753
# Epoch [11/20], step [50/157], loss: 0.5562
# Epoch [11/20], step [60/157], loss: 0.5542
# Epoch [11/20], step [70/157], loss: 0.2175
# Epoch [11/20], step [80/157], loss: 0.4618
# Epoch [11/20], step [90/157], loss: 0.0690
# Epoch [11/20], step [100/157], loss: 0.3937
# Epoch [11/20], step [110/157], loss: 0.4772
# Epoch [11/20], step [120/157], loss: 0.4513
# Epoch [11/20], step [130/157], loss: 0.1402
# Epoch [11/20], step [140/157], loss: 0.1866
# Epoch [11/20], step [150/157], loss: 0.4803
# Epoch [12/20], step [10/157], loss: 0.1657
# Epoch [12/20], step [20/157], loss: 0.3488
# Epoch [12/20], step [30/157], loss: 0.2671
# Epoch [12/20], step [40/157], loss: 0.9757
# Epoch [12/20], step [50/157], loss: 0.3037
# Epoch [12/20], step [60/157], loss: 0.2799
# Epoch [12/20], step [70/157], loss: 0.3444
# Epoch [12/20], step [80/157], loss: 0.3599
# Epoch [12/20], step [90/157], loss: 0.4973
# Epoch [12/20], step [100/157], loss: 0.1631
# Epoch [12/20], step [110/157], loss: 0.0636
# Epoch [12/20], step [120/157], loss: 0.2066
# Epoch [12/20], step [130/157], loss: 0.2011
# Epoch [12/20], step [140/157], loss: 0.2636
# Epoch [12/20], step [150/157], loss: 0.4887
# Epoch [13/20], step [10/157], loss: 0.1256
# Epoch [13/20], step [20/157], loss: 0.0934
# Epoch [13/20], step [30/157], loss: 0.0173
# Epoch [13/20], step [40/157], loss: 0.4151
# Epoch [13/20], step [50/157], loss: 0.1060
# Epoch [13/20], step [60/157], loss: 0.1564
# Epoch [13/20], step [70/157], loss: 0.2683
# Epoch [13/20], step [80/157], loss: 0.3137
# Epoch [13/20], step [90/157], loss: 0.2733
# Epoch [13/20], step [100/157], loss: 0.4430
# Epoch [13/20], step [110/157], loss: 0.2225
# Epoch [13/20], step [120/157], loss: 0.2509
# Epoch [13/20], step [130/157], loss: 0.2433
# Epoch [13/20], step [140/157], loss: 0.0733
# Epoch [13/20], step [150/157], loss: 0.2237
# Epoch [14/20], step [10/157], loss: 0.1054
# Epoch [14/20], step [20/157], loss: 0.7686
# Epoch [14/20], step [30/157], loss: 0.3924
# Epoch [14/20], step [40/157], loss: 0.4270
# Epoch [14/20], step [50/157], loss: 0.0842
# Epoch [14/20], step [60/157], loss: 0.3283
# Epoch [14/20], step [70/157], loss: 0.4402
# Epoch [14/20], step [80/157], loss: 0.0900
# Epoch [14/20], step [90/157], loss: 0.2490
# Epoch [14/20], step [100/157], loss: 0.2572
# Epoch [14/20], step [110/157], loss: 0.3497
# Epoch [14/20], step [120/157], loss: 0.2940
# Epoch [14/20], step [130/157], loss: 0.1377
# Epoch [14/20], step [140/157], loss: 0.0909
# Epoch [14/20], step [150/157], loss: 0.1313
# Epoch [15/20], step [10/157], loss: 0.1008
# Epoch [15/20], step [20/157], loss: 0.3306
# Epoch [15/20], step [30/157], loss: 0.2039
# Epoch [15/20], step [40/157], loss: 0.1866
# Epoch [15/20], step [50/157], loss: 0.1997
# Epoch [15/20], step [60/157], loss: 0.0392
# Epoch [15/20], step [70/157], loss: 0.1316
# Epoch [15/20], step [80/157], loss: 0.2068
# Epoch [15/20], step [90/157], loss: 0.1843
# Epoch [15/20], step [100/157], loss: 0.1946
# Epoch [15/20], step [110/157], loss: 0.1569
# Epoch [15/20], step [120/157], loss: 0.5485
# Epoch [15/20], step [130/157], loss: 0.1346
# Epoch [15/20], step [140/157], loss: 0.0423
# Epoch [15/20], step [150/157], loss: 0.1132
# Epoch [16/20], step [10/157], loss: 0.1983
# Epoch [16/20], step [20/157], loss: 0.0955
# Epoch [16/20], step [30/157], loss: 0.7041
# Epoch [16/20], step [40/157], loss: 0.1582
# Epoch [16/20], step [50/157], loss: 0.0637
# Epoch [16/20], step [60/157], loss: 0.0864
# Epoch [16/20], step [70/157], loss: 0.0566
# Epoch [16/20], step [80/157], loss: 0.1235
# Epoch [16/20], step [90/157], loss: 0.1818
# Epoch [16/20], step [100/157], loss: 0.1567
# Epoch [16/20], step [110/157], loss: 0.2578
# Epoch [16/20], step [120/157], loss: 0.0573
# Epoch [16/20], step [130/157], loss: 0.1994
# Epoch [16/20], step [140/157], loss: 0.2224
# Epoch [16/20], step [150/157], loss: 0.2016
# Epoch [17/20], step [10/157], loss: 0.3045
# Epoch [17/20], step [20/157], loss: 0.3779
# Epoch [17/20], step [30/157], loss: 0.3219
# Epoch [17/20], step [40/157], loss: 0.0707
# Epoch [17/20], step [50/157], loss: 0.7088
# Epoch [17/20], step [60/157], loss: 0.0327
# Epoch [17/20], step [70/157], loss: 0.1789
# Epoch [17/20], step [80/157], loss: 0.0666
# Epoch [17/20], step [90/157], loss: 0.2090
# Epoch [17/20], step [100/157], loss: 0.0271
# Epoch [17/20], step [110/157], loss: 0.5399
# Epoch [17/20], step [120/157], loss: 0.0694
# Epoch [17/20], step [130/157], loss: 0.1180
# Epoch [17/20], step [140/157], loss: 0.1176
# Epoch [17/20], step [150/157], loss: 0.2664
# Epoch [18/20], step [10/157], loss: 0.2147
# Epoch [18/20], step [20/157], loss: 0.2871
# Epoch [18/20], step [30/157], loss: 0.0897
# Epoch [18/20], step [40/157], loss: 0.5313
# Epoch [18/20], step [50/157], loss: 0.1177
# Epoch [18/20], step [60/157], loss: 0.2477
# Epoch [18/20], step [70/157], loss: 0.5500
# Epoch [18/20], step [80/157], loss: 0.2100
# Epoch [18/20], step [90/157], loss: 0.2169
# Epoch [18/20], step [100/157], loss: 0.0280
# Epoch [18/20], step [110/157], loss: 0.1403
# Epoch [18/20], step [120/157], loss: 0.0039
# Epoch [18/20], step [130/157], loss: 0.0323
# Epoch [18/20], step [140/157], loss: 0.0983
# Epoch [18/20], step [150/157], loss: 0.0378
# Epoch [19/20], step [10/157], loss: 0.0562
# Epoch [19/20], step [20/157], loss: 0.0296
# Epoch [19/20], step [30/157], loss: 0.0338
# Epoch [19/20], step [40/157], loss: 0.0526
# Epoch [19/20], step [50/157], loss: 0.2488
# Epoch [19/20], step [60/157], loss: 0.3250
# Epoch [19/20], step [70/157], loss: 0.0070
# Epoch [19/20], step [80/157], loss: 0.0734
# Epoch [19/20], step [90/157], loss: 0.0274
# Epoch [19/20], step [100/157], loss: 0.6802
# Epoch [19/20], step [110/157], loss: 0.1060
# Epoch [19/20], step [120/157], loss: 0.0438
# Epoch [19/20], step [130/157], loss: 0.1871
# Epoch [19/20], step [140/157], loss: 0.1750
# Epoch [19/20], step [150/157], loss: 0.5801
# Epoch [20/20], step [10/157], loss: 0.0237
# Epoch [20/20], step [20/157], loss: 0.2150
# Epoch [20/20], step [30/157], loss: 0.0059
# Epoch [20/20], step [40/157], loss: 0.2926
# Epoch [20/20], step [50/157], loss: 0.1839
# Epoch [20/20], step [60/157], loss: 0.0170
# Epoch [20/20], step [70/157], loss: 0.0456
# Epoch [20/20], step [80/157], loss: 0.0052
# Epoch [20/20], step [90/157], loss: 0.0026
# Epoch [20/20], step [100/157], loss: 0.0023
# Epoch [20/20], step [110/157], loss: 0.1520
# Epoch [20/20], step [120/157], loss: 0.0134
# Epoch [20/20], step [130/157], loss: 0.1760
# Epoch [20/20], step [140/157], loss: 0.0101
# Epoch [20/20], step [150/157], loss: 0.4716

# %%
plot_loss(losses, num_epoch, len(train_loader), 'Loss model v3 full image.png')

# %% [markdown]
# ## Test the model

# %%
# Load model for evaluation
trained_model = ModelV3(input_channels=3)
trained_model.load_state_dict(torch.load('./models/model_v3.h5'))
trained_model.to(device)
# Out:
# ModelV3(
#   (conv1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=12544, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (sigmoid): Sigmoid()
# )

# %%
accuracy, total = evaluate(trained_model, test_loader, device)

# %%
print(f'Accuracy of the network on the {total} test images: {accuracy:.2f}')
# Out:
# Accuracy of the network on the 1254 test images: 83.89
